# %%
pip install rasterio numpy matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import rasterio
import numpy as np
import matplotlib.pyplot as plt

# Set file paths to your B08 and B04 TIFF files
nir_path = "B08.tiff"
red_path = "B04.tiff"
output_path = "ndvi_output.tif"

# Open the bands using rasterio
with rasterio.open(nir_path) as nir_src, rasterio.open(red_path) as red_src:
    nir = nir_src.read(1).astype('float32')
    red = red_src.read(1).astype('float32')
    meta = nir_src.meta

    # Avoid division by zero
    np.seterr(divide='ignore', invalid='ignore')

    # NDVI calculation
    ndvi = (nir - red) / (nir + red)
    
    # Update metadata for output
    meta.update(dtype=rasterio.float32, count=1)

    # Save NDVI to new GeoTIFF
    with rasterio.open(output_path, 'w', **meta) as dst:
        dst.write(ndvi, 1)

    # Display with matplotlib
    plt.figure(figsize=(8, 6))
    plt.title("NDVI")
    plt.imshow(ndvi, cmap='RdYlGn', vmin=-1, vmax=1)
    plt.colorbar(label='NDVI value')
    plt.axis('off')
    plt.show()

# %%
# Set file paths to your B08 and B04 TIFF files
nir_path = "08_br.tiff"
red_path = "04_br.tiff"
output_path = "ndvi_output_br.tif"

# Open the bands using rasterio
with rasterio.open(nir_path) as nir_src, rasterio.open(red_path) as red_src:
    nir = nir_src.read(1).astype('float32')
    red = red_src.read(1).astype('float32')
    meta = nir_src.meta

    # Avoid division by zero
    np.seterr(divide='ignore', invalid='ignore')

    # NDVI calculation
    ndvi = (nir - red) / (nir + red)
    
    # Update metadata for output
    meta.update(dtype=rasterio.float32, count=1)

    # Save NDVI to new GeoTIFF
    with rasterio.open(output_path, 'w', **meta) as dst:
        dst.write(ndvi, 1)

    # Display with matplotlib
    plt.figure(figsize=(8, 6))
    plt.title("NDVI_BROOM")
    plt.imshow(ndvi, cmap='RdYlGn', vmin=-1, vmax=1)
    plt.colorbar(label='NDVI value')
    plt.axis('off')
    plt.show()

# %%
# Set file paths to your B08 and B04 TIFF files
nir_path = "08_hc.tiff"
red_path = "04_hc.tiff"
output_path = "ndvi_output_hc.tif"

# Open the bands using rasterio
with rasterio.open(nir_path) as nir_src, rasterio.open(red_path) as red_src:
    nir = nir_src.read(1).astype('float32')
    red = red_src.read(1).astype('float32')
    meta = nir_src.meta

    # Avoid division by zero
    np.seterr(divide='ignore', invalid='ignore')

    # NDVI calculation
    ndvi = (nir - red) / (nir + red)
    
    # Update metadata for output
    meta.update(dtype=rasterio.float32, count=1)

    # Save NDVI to new GeoTIFF
    with rasterio.open(output_path, 'w', **meta) as dst:
        dst.write(ndvi, 1)

    # Display with matplotlib
    plt.figure(figsize=(8, 6))
    plt.title("NDVI_HALECOMBE")
    plt.imshow(ndvi, cmap='RdYlGn', vmin=-1, vmax=1)
    plt.colorbar(label='NDVI value')
    plt.axis('off')
    plt.show()

# %%
import rasterio
import numpy as np
import matplotlib.pyplot as plt

# Set file paths to your B08 and B04 TIFF files
nir_path = "B08_hc_2017.tiff"
red_path = "B04_hc_2017.tiff"
output_path = "ndvi_output_hc_2017.tif"

# Open the bands using rasterio
with rasterio.open(nir_path) as nir_src, rasterio.open(red_path) as red_src:
    nir = nir_src.read(1).astype('float32')
    red = red_src.read(1).astype('float32')
    meta = nir_src.meta

    # Avoid division by zero
    np.seterr(divide='ignore', invalid='ignore')

    # NDVI calculation
    ndvi = (nir - red) / (nir + red)
    
    # Update metadata for output
    meta.update(dtype=rasterio.float32, count=1)

    # Save NDVI to new GeoTIFF
    with rasterio.open(output_path, 'w', **meta) as dst:
        dst.write(ndvi, 1)

    # Display with matplotlib
    plt.figure(figsize=(8, 6))
    plt.title("NDVI_HALECOMBE")
    plt.imshow(ndvi, cmap='RdYlGn', vmin=-1, vmax=1)
    plt.colorbar(label='NDVI value')
    plt.axis('off')
    plt.show()

# %%
# Set file paths to your B08 and B04 TIFF files
nir_path = "B08_hc_2020.tiff"
red_path = "B04_hc_2020.tiff"
output_path = "ndvi_output_hc_2020.tif"

# Open the bands using rasterio
with rasterio.open(nir_path) as nir_src, rasterio.open(red_path) as red_src:
    nir = nir_src.read(1).astype('float32')
    red = red_src.read(1).astype('float32')
    meta = nir_src.meta

    # Avoid division by zero
    np.seterr(divide='ignore', invalid='ignore')

    # NDVI calculation
    ndvi = (nir - red) / (nir + red)
    
    # Update metadata for output
    meta.update(dtype=rasterio.float32, count=1)

    # Save NDVI to new GeoTIFF
    with rasterio.open(output_path, 'w', **meta) as dst:
        dst.write(ndvi, 1)

    # Display with matplotlib
    plt.figure(figsize=(8, 6))
    plt.title("NDVI_HALECOMBE")
    plt.imshow(ndvi, cmap='RdYlGn', vmin=-1, vmax=1)
    plt.colorbar(label='NDVI value')
    plt.axis('off')
    plt.show()

# %%
# Set file paths to your B08 and B04 TIFF files
nir_path = "B08_br_2017.tiff"
red_path = "B04_br_2017.tiff"
output_path = "ndvi_output_br_2017.tif"

# Open the bands using rasterio
with rasterio.open(nir_path) as nir_src, rasterio.open(red_path) as red_src:
    nir = nir_src.read(1).astype('float32')
    red = red_src.read(1).astype('float32')
    meta = nir_src.meta

    # Avoid division by zero
    np.seterr(divide='ignore', invalid='ignore')

    # NDVI calculation
    ndvi = (nir - red) / (nir + red)
    
    # Update metadata for output
    meta.update(dtype=rasterio.float32, count=1)

    # Save NDVI to new GeoTIFF
    with rasterio.open(output_path, 'w', **meta) as dst:
        dst.write(ndvi, 1)

    # Display with matplotlib
    plt.figure(figsize=(8, 6))
    plt.title("NDVI_HALECOMBE")
    plt.imshow(ndvi, cmap='RdYlGn', vmin=-1, vmax=1)
    plt.colorbar(label='NDVI value')
    plt.axis('off')
    plt.show()

# %%
# Set file paths to your B08 and B04 TIFF files
nir_path = "B08_br_2020.tiff"
red_path = "B04_br_2020.tiff"
output_path = "ndvi_output_br_2020.tif"

# Open the bands using rasterio
with rasterio.open(nir_path) as nir_src, rasterio.open(red_path) as red_src:
    nir = nir_src.read(1).astype('float32')
    red = red_src.read(1).astype('float32')
    meta = nir_src.meta

    # Avoid division by zero
    np.seterr(divide='ignore', invalid='ignore')

    # NDVI calculation
    ndvi = (nir - red) / (nir + red)
    
    # Update metadata for output
    meta.update(dtype=rasterio.float32, count=1)

    # Save NDVI to new GeoTIFF
    with rasterio.open(output_path, 'w', **meta) as dst:
        dst.write(ndvi, 1)

    # Display with matplotlib
    plt.figure(figsize=(8, 6))
    plt.title("NDVI_HALECOMBE")
    plt.imshow(ndvi, cmap='RdYlGn', vmin=-1, vmax=1)
    plt.colorbar(label='NDVI value')
    plt.axis('off')
    plt.show()
